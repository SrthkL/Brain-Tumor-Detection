# %%
import random
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import sklearn
from sklearn.metrics import accuracy_score, confusion_matrix
import glob
import numpy as np
import pandas as pd 
import cv2 as cv
import os

# %%
#loading data
path1 = r"C:\Users\capta\Documents\brain_tumor_dataset\yes"
tumor = []
for i in glob.iglob(os.path.join(path1, '*')):
    img = cv.imread(i)
    tumor.append(img)

# %%
path2 = r"C:\Users\capta\Documents\brain_tumor_dataset\no"
healthy = []
for i in glob.iglob(os.path.join(path2, '*')):
    img = cv.imread(i)
    healthy.append(img)

# %%
class Data(Dataset):
    def __init__(self):
        
        path2 = r"C:\Users\capta\Documents\brain_tumor_dataset\no"
        healthy = []
        for i in glob.iglob(os.path.join(path2, '*')):
            img = cv.imread(i)
            img = cv.resize(img,(128,128))
            b,g,r = cv.split(img)
            img= cv.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0], img.shape[1]))
            healthy.append(img)
        path1 = r"C:\Users\capta\Documents\brain_tumor_dataset\yes"
        tumor = []
        for i in glob.iglob(os.path.join(path1, '*')):
            img = cv.imread(i)
            img= cv.resize(img,(128,128))
            b,g,r = cv.split(img)
            img= cv.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0], img.shape[1]))
            tumor.append(img)
        tumor = np.array(tumor,dtype = np.float32)
        healthy = np.array(healthy,dtype = np.float32)
        healthy_labels =np.zeros(healthy.shape[0],dtype = np.float32)
        tumor_labels = np.ones(tumor.shape[0], dtype = np.float32)
        self.images = np.concatenate((tumor,healthy), axis = 0)
        self.labels = np.concatenate((tumor_labels, healthy_labels))

    def __len__(self):
        return self.images.shape[0]
    def __getitem__(self,index):
        sample = {'image': self.images[index], 'label': self.labels[index]}
        return sample
    def normalize(self):
        self.images = self.images / 255.0

# %%
import torch.nn.functional as F
class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.cnn_model = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5),
        nn.Tanh(),
        nn.AvgPool2d(kernel_size=2, stride=5),
        nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
        nn.Tanh(),
        nn.AvgPool2d(kernel_size=2, stride=5))
        
        self.fc_model = nn.Sequential(
        nn.Linear(in_features=256, out_features=120),
        nn.Tanh(),
        nn.Linear(in_features=120, out_features=84),
        nn.Tanh(),
        nn.Linear(in_features=84, out_features=1))

    def forward(self,x):
        x = self.cnn_model(x)
        x = x.view(x.size(0),-1)
        x = self.fc_model(x)
        x = F.sigmoid(x)
        return x

# %%
mri_dataset = Data()
mri_dataset.normalize()

# %%
import matplotlib.pyplot as plt
names = {0:'Healthy', 1:'Tumor'}
dataloader = DataLoader(mri_dataset, shuffle=True)
for i, sample in enumerate(dataloader):
    img = sample['image'].squeeze()
    img = img.reshape((img.shape[1],img.shape[2],img.shape[0]))
    plt.title(names[sample['label'].item()])
    plt.imshow(img)
    plt.show()
    if i == 5:
        break

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
mri_dataset = Data()
mri_dataset.normalize()
device = torch.device('cuda:0')
model = CNN().to(device)
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)

# %%
model.eval()
outputs= []
y_true = []
with torch.no_grad():
    for D in dataloader:
        image = D['image'].to(device)
        label = D['label'].to(device)
        y_hat = model(image)
        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())

# %%
outputs = np.concatenate(outputs, axis=0).squeeze()
y_true = np.concatenate(y_true,axis = 0).squeeze()

# %%
def threshold(scores,threshold = 0.50, minimum = 0, maximum = 1.0):
    x = np.array(list(scores))
    x[x>=threshold]= maximum
    x[x<threshold] = minimum
    return x

# %%
accuracy_score(y_true, threshold(outputs))
# Out:
# 0.38735177865612647

# %%
import seaborn as sns

plt.figure(figsize=(16,9))
cm = confusion_matrix(y_true, threshold(outputs))
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax, annot_kws={"size": 20})

# labels, title and ticks
ax.set_xlabel('Predicted labels', fontsize=20)
ax.set_ylabel('True labels', fontsize=20) 
ax.set_title('Confusion Matrix', fontsize=20)
ax.xaxis.set_ticklabels(['Healthy','Tumor'], fontsize=20)
ax.yaxis.set_ticklabels(['Tumor','Healthy'], fontsize=20)
# Out:
# [Text(0, 0.5, 'Tumor'), Text(0, 1.5, 'Healthy')]

# %%
plt.figure(figsize=(16,9))
plt.plot(outputs)
plt.axvline(x=len(tumor), color='r', linestyle='--')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 plt.figure(figsize=(16,9))
#       2 plt.plot(outputs)
# ----> 3 plt.axvline(x=len(tumor), color='r', linestyle='--')
#       4 plt.grid()
#
# NameError: name 'tumor' is not defined

# %%
eta = 0.0001
EPOCH = 400
optimizer = torch.optim.Adam(model.parameters(), lr=eta)
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=True)
model.train()
# Out:
# CNN(
#   (cnn_model): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): Tanh()
#     (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#     (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): Tanh()
#     (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=256, out_features=120, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=120, out_features=84, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=84, out_features=1, bias=True)
#   )
# )

# %%
for epoch in range(1, EPOCH):
    losses = []
    for D in dataloader:
        optimizer.zero_grad()
        data = D['image'].to(device)
        label = D['label'].to(device)
        y_hat = model(data)
        # define loss function
        error = nn.BCELoss() 
        loss = torch.sum(error(y_hat.squeeze(), label))
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    if (epoch+1) % 10 == 0:
        print('Train Epoch: {}\tLoss: {:.6f}'.format(epoch+1, np.mean(losses)))
# Out:
# Train Epoch: 10	Loss: 0.625328
# Train Epoch: 20	Loss: 0.592791
# Train Epoch: 30	Loss: 0.550964
# Train Epoch: 40	Loss: 0.539063
# Train Epoch: 50	Loss: 0.527446
# Train Epoch: 60	Loss: 0.512336
# Train Epoch: 70	Loss: 0.497053
# Train Epoch: 80	Loss: 0.482064
# Train Epoch: 90	Loss: 0.463610
# Train Epoch: 100	Loss: 0.441379
# Train Epoch: 110	Loss: 0.428403
# Train Epoch: 120	Loss: 0.414442
# Train Epoch: 130	Loss: 0.400052
# Train Epoch: 140	Loss: 0.384397
# Train Epoch: 150	Loss: 0.373666
# Train Epoch: 160	Loss: 0.361100
# Train Epoch: 170	Loss: 0.344515
# Train Epoch: 180	Loss: 0.332379
# Train Epoch: 190	Loss: 0.321552
# Train Epoch: 200	Loss: 0.311241
# Train Epoch: 210	Loss: 0.292700
# Train Epoch: 220	Loss: 0.279523
# Train Epoch: 230	Loss: 0.267430
# Train Epoch: 240	Loss: 0.242653
# Train Epoch: 250	Loss: 0.232527
# Train Epoch: 260	Loss: 0.207481
# Train Epoch: 270	Loss: 0.191299
# Train Epoch: 280	Loss: 0.171993
# Train Epoch: 290	Loss: 0.154219
# Train Epoch: 300	Loss: 0.136621
# Train Epoch: 310	Loss: 0.121690
# Train Epoch: 320	Loss: 0.105060
# Train Epoch: 330	Loss: 0.093273
# Train Epoch: 340	Loss: 0.081052
# Train Epoch: 350	Loss: 0.074238
# Train Epoch: 360	Loss: 0.059607
# Train Epoch: 370	Loss: 0.048840
# Train Epoch: 380	Loss: 0.038924
# Train Epoch: 390	Loss: 0.033387
# Train Epoch: 400	Loss: 0.027368

# %%
model.eval()
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)
outputs=[]
y_true = []
with torch.no_grad():
    for D in dataloader:
        image =  D['image'].to(device)
        label = D['label'].to(device)
        
        y_hat = model(image)
        
        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())
        
outputs = np.concatenate( outputs, axis=0 )
y_true = np.concatenate( y_true, axis=0 )

# %%
accuracy_score(y_true, threshold(outputs))
# Out:
# 1.0

# %%
cm = confusion_matrix(y_true, threshold(outputs))
plt.figure(figsize=(16,9))

ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Tumor','Healthy'])
ax.yaxis.set_ticklabels(['Tumor','Healthy'])
# Out:
# [Text(0, 0.5, 'Tumor'), Text(0, 1.5, 'Healthy')]

# %%
plt.figure(figsize=(16,9))
plt.plot(outputs)
plt.axvline(x=len(tumor), color='r', linestyle='--')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 plt.figure(figsize=(16,9))
#       2 plt.plot(outputs)
# ----> 3 plt.axvline(x=len(tumor), color='r', linestyle='--')
#       4 plt.grid()
#
# NameError: name 'tumor' is not defined
